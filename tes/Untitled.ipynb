# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DF = pd.read_csv('../2023빅콘테스트_어드밴스드리그_예술의전당.csv', parse_dates=['tran_date', 'tran_time', 'play_date', 'play_st_time', 'pre_open_date', 'open_date']
                , date_format= "%Y%m%d" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 DF = pd.read_csv('../2023빅콘테스트_어드밴스드리그_예술의전당.csv', parse_dates=['tran_date', 'tran_time', 'play_date', 'play_st_time', 'pre_open_date', 'open_date']
#       2                 , date_format= "%Y%m%d" )
#
# File c:\Users\kdp\anaconda3\envs\My_38\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\kdp\anaconda3\envs\My_38\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 0        50.0      F                골드                무료                그린
# 1         NaN    NaN               NaN               NaN               NaN
# 2         NaN    NaN               NaN               NaN               NaN
# 3         NaN    NaN               NaN               NaN               NaN
# 4        50.0      M                무료               NaN               NaN
# ...       ...    ...               ...               ...               ...
# 1920863   NaN    NaN               NaN               NaN               NaN
# 1920864  20.0      F                무료              싹틔우미               NaN
# 1920865  50.0      F                블루                무료                그린
# 1920866   NaN    NaN               NaN               NaN               NaN
# 1920867   NaN    NaN               NaN               NaN               NaN
#
# ...

# %%
DF.columns
# Out:
# Index(['age', 'gender', 'membership_type_1', 'membership_type_2',
#        'membership_type_3', 'membership_type_4', 'membership_type_5',
#        'membership_type_6', 'tran_date', 'tran_time', 'play_date',
#        'play_st_time', 'seat', 'price', 'ticket_cancel', 'discount_type',
#        'performance_code', 'pre_open_date', 'open_date', 'genre', 'place',
#        'running_time', 'intermission', 'member_yn'],
#       dtype='object')

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920868 entries, 0 to 1920867
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   age                float64
#  1   gender             object
#  2   membership_type_1  object
#  3   membership_type_2  object
#  4   membership_type_3  object
#  5   membership_type_4  object
#  6   membership_type_5  object
#  7   membership_type_6  float64
#  8   tran_date          datetime64[ns]
#  9   tran_time          object
#  10  play_date          datetime64[ns]
#  11  play_st_time       object
#  12  seat               object
#  13  price              int64
#  14  ticket_cancel      int64
#  15  discount_type      object
#  16  performance_code   int64
#  17  pre_open_date      datetime64[ns]
#  18  open_date          datetime64[ns]
#  19  genre              object
#  20  place              object
#  21  running_time       int64
#  22  intermission       int64
# ...

# %%
priceDF = DF.drop(columns=['age', 'gender', 'play_st_time', 'running_time', 'intermission', 'member_yn', 'tran_time'])
priceDF
# Out:
#         membership_type_1 membership_type_2 membership_type_3  \
# 0                      골드                무료                그린
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                      무료               NaN               NaN
# ...                   ...               ...               ...
# 1920863               NaN               NaN               NaN
# 1920864                무료              싹틔우미               NaN
# 1920865                블루                무료                그린
# 1920866               NaN               NaN               NaN
# 1920867               NaN               NaN               NaN
#
#         membership_type_4 membership_type_5  membership_type_6  tran_date  \
# 0                     NaN               NaN                NaN 2022-01-14
# ...
